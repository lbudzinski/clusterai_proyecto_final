# %% [markdown]
# ## Importar librerias

# %%
# importamos las librerías necesarias para trabajar.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 42D6-A5A6
#
#  Directory of C:\Users\Administrator.OMSWV4XTWIYHGZM\Documents\ClusterAI\proyecto_grupal
#
# 22/11/2019  01:32 p.m.    <DIR>          .
# 22/11/2019  01:32 p.m.    <DIR>          ..
# 21/11/2019  06:37 p.m.    <DIR>          .ipynb_checkpoints
# 17/11/2019  03:10 a.m.         1.014.930 7b479f8c10c098e4932b77b8356a552d016f.pdf
# 20/10/2019  09:45 a.m.           357.491 aclaraciones-metodologicas-suaci-2017.pdf
# 22/11/2019  01:06 a.m.         1.134.874 Aplicamos el algoritmo de K.docx
# 18/11/2019  04:50 p.m.         1.040.818 clusterai_template_poster.pptx
# 18/11/2019  10:01 p.m.         1.092.862 clustering_suaci_categorias.ipynb
# 18/11/2019  09:49 p.m.           383.890 clustering_suaci_subcat.ipynb
# 22/11/2019  01:32 p.m.    <DIR>          Entregar
# 21/11/2019  07:58 p.m.    <DIR>          figuras
# 20/10/2019  09:47 a.m.         2.807.857 gcba_suaci_comunas 2013-2015.csv
# ...

# %% [markdown]
# ## Importar Data

# %% [markdown]
# Voy a trabajar con 3 datasets en simultaneo

# %%
# importamos los dataset para el tabajo
# importante detallar que el delimiter indica como estan separadas las columnas en el dataframe.
suaci_2017 = pd.read_csv(r'C:\Users\Administrator.OMSWV4XTWIYHGZM\Documents\ClusterAI\proyecto_grupal/sistema-unico-de-atencion-ciudadana-2017.csv', delimiter=';')
suaci_2018 = pd.read_csv(r'C:\Users\Administrator.OMSWV4XTWIYHGZM\Documents\ClusterAI\proyecto_grupal/sistema-unico-de-atencion-ciudadana-2018.csv', delimiter=',')
suaci_2019 = pd.read_csv(r'C:\Users\Administrator.OMSWV4XTWIYHGZM\Documents\ClusterAI\proyecto_grupal/sistema-unico-de-atencion-ciudadana-2019.csv', delimiter=',')

# %%
suaci_2017.head()
# Out:
#       CONTACTO  PERIODO               CATEGORIA           SUBCATEGORIA  \
# 0  00005735/17   201701        CALLES Y VEREDAS   REPARACION DE VEREDA
# 1  00004008/17   201701    MEDIOS DE TRANSPORTE             BICICLETAS
# 2  00004187/17   201701    MEDIOS DE TRANSPORTE             BICICLETAS
# 3  00011267/17   201701    MEDIOS DE TRANSPORTE             BICICLETAS
# 4  00011302/17   201701  LIMPIEZA Y RECOLECCION  CESTOS Y CONTENEDORES
#
#                                CONCEPTO TIPO_PRESTACION FECHA_INGRESO  \
# 0                  REPARACION DE VEREDA       SOLICITUD      2/1/2017
# 1           INCONVENIENTES CON ECOBICIS           QUEJA      2/1/2017
# 2           INCONVENIENTES CON ECOBICIS           QUEJA      2/1/2017
# 3           INCONVENIENTES CON ECOBICIS           QUEJA      3/1/2017
# 4  INSTALACION/REPARACION DE CONTENEDOR       SOLICITUD      3/1/2017
#
#    HORA_INGRESO DOMICILIO_CGPC  DOMICILIO_BARRIO     DOMICILIO_CALLE  \
# ...

# %%
suaci_2018.head()
# Out:
#       contacto  periodo                   categoria         subcategoria  \
# 0  00000001/18   201801                    TRÁNSITO        DENUNCIA VIAL
# 1  00000002/18   201801                    TRÁNSITO        DENUNCIA VIAL
# 2  00000003/18   201801                    TRÁNSITO        DENUNCIA VIAL
# 3  00000004/18   201801  ARBOLADO Y ESPACIOS VERDES  PLANTACIÓN DE ÁRBOL
# 4  00000005/18   201801                    TRÁNSITO        DENUNCIA VIAL
#
#                    concepto tipo_prestacion fecha_ingreso   hora_ingreso  \
# 0  VEHÍCULO MAL ESTACIONADO        DENUNCIA    2018-01-01  12:03:30 a.m.
# 1  VEHÍCULO MAL ESTACIONADO        DENUNCIA    2018-01-01  12:19:33 a.m.
# 2  VEHÍCULO MAL ESTACIONADO        DENUNCIA    2018-01-01  12:19:33 a.m.
# 3       PLANTACIÓN DE ÁRBOL       SOLICITUD    2018-01-01  12:19:36 a.m.
# 4  VEHÍCULO MAL ESTACIONADO        DENUNCIA    2018-01-01  12:20:33 a.m.
#
#   domicilio_cgpc domicilio_barrio        domicilio_calle  domicilio_altura  \
# ...

# %%
suaci_2019.head()
# Out:
#       contacto  periodo                   categoria         subcategoria  \
# 0  00000001/19   201901                    TRÁNSITO        DENUNCIA VIAL
# 1  00000002/19   201901                    TRÁNSITO        DENUNCIA VIAL
# 2  00000003/19   201901  ARBOLADO Y ESPACIOS VERDES  PLANTACIÓN DE ÁRBOL
# 3  00000005/19   201901                    TRÁNSITO        DENUNCIA VIAL
# 4  00000006/19   201901                    TRÁNSITO        DENUNCIA VIAL
#
#                    concepto tipo_prestacion fecha_ingreso   hora_ingreso  \
# 0  VEHÍCULO MAL ESTACIONADO        DENUNCIA    2019-01-01  12:11:17 a.m.
# 1  VEHÍCULO MAL ESTACIONADO        DENUNCIA    2019-01-01  12:13:19 a.m.
# 2       PLANTACIÓN DE ÁRBOL       SOLICITUD    2019-01-01  12:23:32 a.m.
# 3  VEHÍCULO MAL ESTACIONADO        DENUNCIA    2019-01-01  12:48:20 a.m.
# 4  VEHÍCULO MAL ESTACIONADO        DENUNCIA    2019-01-01  01:02:33 a.m.
#
#   domicilio_cgpc domicilio_barrio         domicilio_calle  domicilio_altura  \
# ...

# %%
suaci_2017.shape
# Out:
# (691878, 18)

# %%
suaci_2018.shape
# Out:
# (893291, 19)

# %%
suaci_2019.shape
# Out:
# (626101, 19)

# %% [markdown]
# En principio voy a analizar los 3 datasets por seprado

# %% [markdown]
# ## Limpiar Data

# %% [markdown]
# Voy a revisar cuantos datos nulos tiene cada dataset. Voy a eliminar las columnas con mas del 50% de datos nulos. Voy a eliminar los registros nulos de las columnas que presenten nulos siempre y cuando no elimine mas del 20% del datset total

# %%
#suaci 2017
total2017 = suaci_2017.isnull().sum().sort_values(ascending=False)
percent2017 = (suaci_2017.isnull().sum()/suaci_2017.isnull().count()).sort_values(ascending=False)
missing_data2017 = pd.concat([total2017, percent2017], axis=1, keys=['Total', 'Percent'])
missing_data2017.head(18)
# Out:
#                             Total   Percent
# DOMICILIO_ESQUINA_PROXIMA  640551  0.925815
# DOMICILIO_ALTURA            51327  0.074185
# SUBCATEGORIA                  673  0.000973
# ESTADO_DEL_CONTACTO             0  0.000000
# HORA_INGRESO                    0  0.000000
# PERIODO                         0  0.000000
# CATEGORIA                       0  0.000000
# CONCEPTO                        0  0.000000
# TIPO_PRESTACION                 0  0.000000
# FECHA_INGRESO                   0  0.000000
# DOMICILIO_CGPC                  0  0.000000
# GENERO                          0  0.000000
# DOMICILIO_BARRIO                0  0.000000
# DOMICILIO_CALLE                 0  0.000000
# LAT                             0  0.000000
# LONG                            0  0.000000
# CANAL                           0  0.000000
# CONTACTO                        0  0.000000

# %% [markdown]
# Los unicos datos que me interesan que presentan nulos con los de la feature SUBCATEGORIA. Voy a eliminar directamente esos registros porque son muy pocos (673) y a seguir adelante

# %%
suaci_2017_clean = suaci_2017.dropna(subset=['SUBCATEGORIA'])

# %%
suaci_2017_clean=suaci_2017_clean.drop(['DOMICILIO_ESQUINA_PROXIMA', 'DOMICILIO_ALTURA'], axis=1)

# %%
suaci_2017_clean.shape
# Out:
# (691205, 16)

# %% [markdown]
# Repito lo mismo para los demas datasets

# %%
#suaci 2018
total2018 = suaci_2018.isnull().sum().sort_values(ascending=False)
percent2018 = (suaci_2018.isnull().sum()/suaci_2018.isnull().count()).sort_values(ascending=False)
missing_data2018 = pd.concat([total2018, percent2018], axis=1, keys=['Total', 'Percent'])
missing_data2018.head(19)
# Out:
#                             Total   Percent
# domicilio_esquina_proxima  785794  0.879662
# fecha_cierre_contacto      124315  0.139165
# domicilio_altura           107497  0.120338
# subcategoria                14083  0.015765
# genero                         11  0.000012
# hora_ingreso                    0  0.000000
# periodo                         0  0.000000
# categoria                       0  0.000000
# concepto                        0  0.000000
# tipo_prestacion                 0  0.000000
# fecha_ingreso                   0  0.000000
# domicilio_barrio                0  0.000000
# domicilio_cgpc                  0  0.000000
# estado_del_contacto             0  0.000000
# domicilio_calle                 0  0.000000
# lat                             0  0.000000
# long                            0  0.000000
# canal                           0  0.000000
# contacto                        0  0.000000

# %% [markdown]
# Esta situacion es un poco mas complicada porque me interesan tanto fecha_cierre_contacto como subcategoria. Voy a eliminar los registros porque me quedo con aprox 90% del dataset.
# Aquí se hace una distinción importante: analizando los nulos del feature fecha_cierre_contacto, el 100% de los casos se corresponde con contactos cuyo estado_del_contacto se categoriza como 'Abierto'. Por tanto, en este caso particular, no estamos en presencia de errores u omisiones en la carga de los datos, sino que ES CORRECTO el valor nulo para estos samples.
# Por cuestiones de simplificación del modelado y análisis, voy a quitar estos registros del dataset; sin embargo, se tendrán en cuenta al analizar el estado de los contactos más adelante.

# %%
suaci_2018_clean = suaci_2018.dropna(subset=['fecha_cierre_contacto', 'subcategoria', 'genero'])

# %%
suaci_2018_clean=suaci_2018_clean.drop(['domicilio_esquina_proxima', 'domicilio_altura'], axis=1)

# %%
suaci_2018_clean.shape
# Out:
# (758980, 17)

# %%
#suaci 2019
total2019 = suaci_2019.isnull().sum().sort_values(ascending=False)
percent2019 = (suaci_2019.isnull().sum()/suaci_2019.isnull().count()).sort_values(ascending=False)
missing_data2019 = pd.concat([total2019, percent2019], axis=1, keys=['Total', 'Percent'])
missing_data2019.head(19)
# Out:
#                             Total   Percent
# domicilio_esquina_proxima  556126  0.888237
# fecha_cierre_contacto       82039  0.131032
# domicilio_altura            69975  0.111763
# subcategoria                 9573  0.015290
# genero                          4  0.000006
# hora_ingreso                    0  0.000000
# periodo                         0  0.000000
# categoria                       0  0.000000
# concepto                        0  0.000000
# tipo_prestacion                 0  0.000000
# fecha_ingreso                   0  0.000000
# domicilio_barrio                0  0.000000
# domicilio_cgpc                  0  0.000000
# estado_del_contacto             0  0.000000
# domicilio_calle                 0  0.000000
# lat                             0  0.000000
# long                            0  0.000000
# canal                           0  0.000000
# contacto                        0  0.000000

# %%
suaci_2019_clean = suaci_2019.dropna(subset=['fecha_cierre_contacto', 'subcategoria', 'genero'])

# %%
suaci_2019_clean = suaci_2019_clean.drop(['domicilio_esquina_proxima', 'domicilio_altura'], axis=1)

# %%
suaci_2019_clean.shape
# Out:
# (542027, 17)

# %% [markdown]
# Ahora si, con los datasets limpios de NaNs voy a analizar la informacion que contienen

# %% [markdown]
# ## Visualizar Data

# %% [raw]
# 1. Numero de tramites por Comuna en los años 2017-2019. De que comunas parten la mayoria de los tramies/reclamos?

# %%
fig = plt.figure(figsize=(15,12))
fig.subplots_adjust(top=0.9, wspace=0.3, hspace=0.5)
fig.suptitle('Tramites por Comuna por Año', size = 18)

#2017
ax1 = fig.add_subplot(2,2,1)
ax1 = sns.countplot(x="DOMICILIO_CGPC",data=suaci_2017_clean, palette = "RdYlGn", 
                   order=['COMUNA 1', 'COMUNA 2', 'COMUNA 3', 'COMUNA 4', 'COMUNA 5','COMUNA 6','COMUNA 7','COMUNA 8','COMUNA 9','COMUNA 10','COMUNA 11','COMUNA 12','COMUNA 13','COMUNA 14','COMUNA 15'])
ax1.set_xticklabels(ax1.get_xticklabels(), rotation=80, ha="right")
ax1.set_xlabel("Comunas",size = 14)
ax1.set_ylabel("Numero de tramites",size = 14)
ax1.set_title('2017',size = 15)

#2018
ax2 = fig.add_subplot(2,2,2)
ax2 = sns.countplot(x="domicilio_cgpc",data=suaci_2018_clean, palette = "RdYlGn", 
                   order=['COMUNA 1', 'COMUNA 2', 'COMUNA 3', 'COMUNA 4', 'COMUNA 5','COMUNA 6','COMUNA 7','COMUNA 8','COMUNA 9','COMUNA 10','COMUNA 11','COMUNA 12','COMUNA 13','COMUNA 14','COMUNA 15'])
ax2.set_xticklabels(ax2.get_xticklabels(), rotation=80, ha="right")
ax2.set_xlabel("Comunas",size = 14)
ax2.set_ylabel("Numero de tramites",size = 14)
ax2.set_title('2018',size = 15)

#2019
ax3 = fig.add_subplot(2,2,3)
ax3 = sns.countplot(x="domicilio_cgpc",data=suaci_2018_clean, palette = "RdYlGn", 
                   order=['COMUNA 1', 'COMUNA 2', 'COMUNA 3', 'COMUNA 4', 'COMUNA 5','COMUNA 6','COMUNA 7','COMUNA 8','COMUNA 9','COMUNA 10','COMUNA 11','COMUNA 12','COMUNA 13','COMUNA 14','COMUNA 15'])
ax3.set_xticklabels(ax3.get_xticklabels(), rotation=80, ha="right")
ax3.set_xlabel("Comunas",size = 14)
ax3.set_ylabel("Numero de tramites",size = 14)
ax3.set_title('2019',size = 15)

plt.show()

# %% [markdown]
# 2. Numeros de tramites por Categorias en los años 2017-2019. De que categorias son la mayoria de los tramies/reclamos?

# %%
fig = plt.figure(figsize=(17,11))
fig.subplots_adjust(top=0.9, wspace=0.8, hspace=0.3)
fig.suptitle('Tramites por Categoria por Año', size = 18)

#2017
ax1 = fig.add_subplot(2,2,1)
ax1 = sns.countplot(y="CATEGORIA",data=suaci_2017_clean, palette = "RdYlGn",
                   order = ['ALUMBRADO','ARBOLADO Y ESPACIOS VERDES','CALLES Y VEREDAS','CONTROL EDILICIO, OBRAS Y CATASTRO',
                            'FISCALIZACIÓN ACTIVIDADES COMERCIALES','LIMPIEZA Y RECOLECCION','MEDIOS DE TRANSPORTE',
                            'ORDENAMIENTO DEL ESPACIO PUBLICO','PLUVIALES','RECICLADO Y PROTECCION AMBIENTAL',
                            'SALUD Y SERVICIOS SOCIALES','SEGURIDAD','TRAMITES Y SERVICIOS',
                            'TRANSITO']) 
ax1.set_xlabel("Numero de tramites",size = 14)
ax1.set_ylabel("Categorias",size = 14)
ax1.set_title('2017',size = 15)

#2018
ax2 = fig.add_subplot(2,2,2)
ax2 = sns.countplot(y="categoria",data=suaci_2018_clean, palette = "RdYlGn",
                   order = ['ALUMBRADO','ARBOLADO Y ESPACIOS VERDES','CALLES Y VEREDAS','CONTROL EDILICIO, OBRAS Y CATASTRO',
                            'FISCALIZACIÓN ACTIVIDADES COMERCIALES','LIMPIEZA Y RECOLECCIÓN','MEDIOS DE TRANSPORTE',
                            'ORDENAMIENTO DEL ESPACIO PÚBLICO','PLUVIALES','RECICLADO Y PROTECCIÓN AMBIENTAL',
                            'SALUD Y SERVICIOS SOCIALES','SEGURIDAD','TRÁMITES Y SERVICIOS',
                            'TRÁNSITO']) 
ax2.set_xlabel("Numero de tramites",size = 14)
ax2.set_ylabel("Categorias",size = 14)
ax2.set_title('2018',size = 15)

#2019
ax3 = fig.add_subplot(2,2,3)
ax3 = sns.countplot(y="categoria",data=suaci_2019_clean, palette = "RdYlGn",
                   order = ['ALUMBRADO','ARBOLADO Y ESPACIOS VERDES','CALLES Y VEREDAS','CONTROL EDILICIO, OBRAS Y CATASTRO',
                            'FISCALIZACIÓN ACTIVIDADES COMERCIALES','LIMPIEZA Y RECOLECCIÓN','MEDIOS DE TRANSPORTE',
                            'ORDENAMIENTO DEL ESPACIO PÚBLICO','PLUVIALES','RECICLADO Y PROTECCIÓN AMBIENTAL',
                            'SALUD Y SERVICIOS SOCIALES','SEGURIDAD','TRÁMITES Y SERVICIOS',
                            'TRÁNSITO']) 
ax3.set_xlabel("Numero de tramites",size = 14)
ax3.set_ylabel("Categorias",size = 14)
ax3.set_title('2019',size = 15)

plt.show()

# %% [markdown]
# Los datos de los años 2017-2019 se comportan de manera muy similar en cuanto a la tendencia de la distrubucion del numero de tramites.

# %% [markdown]
# 3. Dentro de las 2 categorias (TRANSITO y LIMPIEZA Y RECOLECCION) que tienen mayor numero de reclamos... cuales subcategorias son mas importanes?

# %% [markdown]
# TRANSITO

# %%
#2017
suaci_2017_tr = suaci_2017_clean.loc[suaci_2017_clean['CATEGORIA'] == 'TRANSITO']
#suaci_2017_tr.head()

#2018
suaci_2018_tr = suaci_2018_clean.loc[suaci_2018_clean['categoria'] == 'TRÁNSITO']
#suaci_2018_tr.head()

#2019
suaci_2019_tr = suaci_2019_clean.loc[suaci_2019_clean['categoria'] == 'TRÁNSITO']
#suaci_2019_tr.head()

# %%
fig = plt.figure(figsize=(6,8))
fig.subplots_adjust(top=0.85, hspace=1.2)
fig.suptitle('Subcategorias de los Tramites de Tránsito por Año', size = 18)

#2017
#en el dataset 2017 habia mas subcategorias, pero solo me quedé con las 3 quepresentaban el dataset 2018 y 2019 para 
#comprar siempre las mismas variables
ax1 = fig.add_subplot(3,1,1)
ax1 = sns.countplot(y="SUBCATEGORIA",data= suaci_2017_tr, palette = "RdYlGn",
                   order = ['DENUNCIA VIAL', 'VEHICULOS ABANDONADOS', 'SEMAFOROS'])
ax1.set_xlabel("Numero de tramites",size = 14)
ax1.set_ylabel("Subcategorias",size = 14)
ax1.set_title('2017',size = 15)


#2018
ax2 = fig.add_subplot(3,1,2)
ax2 = sns.countplot(y="subcategoria",data= suaci_2018_tr, palette = "RdYlGn",
                   order = suaci_2018_tr['subcategoria'].value_counts().index)
ax2.set_xlabel("Numero de tramites",size = 14)
ax2.set_ylabel("Subcategorias",size = 14)
ax2.set_title('2018',size = 15)


#2019
ax3 = fig.add_subplot(3,1,3)
ax3 = sns.countplot(y="subcategoria",data= suaci_2019_tr, palette = "RdYlGn",
                   order = suaci_2019_tr['subcategoria'].value_counts().index)
ax3.set_xlabel("Numero de tramites",size = 14)
ax3.set_ylabel("Subcategorias",size = 14)
ax3.set_title('2019',size = 15)

plt.show()

# %% [markdown]
# LIMPIEZA Y RECOLECCION

# %%
#2017
suaci_2017_lyr = suaci_2017_clean.loc[suaci_2017_clean['CATEGORIA'] == 'LIMPIEZA Y RECOLECCION']
#suaci_2017_lyr.head()

#2018
suaci_2018_lyr = suaci_2018_clean.loc[suaci_2018_clean['categoria'] == 'LIMPIEZA Y RECOLECCIÓN']
#suaci_2018_lyr.head()

#2019
suaci_2019_lyr = suaci_2019_clean.loc[suaci_2019_clean['categoria'] == 'LIMPIEZA Y RECOLECCIÓN']
#suaci_2018_lyr.head()

# %%
fig = plt.figure(figsize=(6,10))
fig.subplots_adjust(top=0.85, hspace=1.2)
fig.suptitle('Subcategorias de los Tramites de Limpieza y Recoleccion por Año', size = 18)

#2017
ax1 = fig.add_subplot(3,1,1)
ax1 = sns.countplot(y="SUBCATEGORIA",data= suaci_2017_lyr, palette = "RdYlGn",
                   order = suaci_2017_lyr['SUBCATEGORIA'].value_counts().index)
ax1.set_xlabel("Numero de tramites",size = 14)
ax1.set_ylabel("Subcategorias",size = 14)
ax1.set_title('2017',size = 15)


#2018
ax = fig.add_subplot(3,1,2)
ax2 = sns.countplot(y="subcategoria",data= suaci_2018_lyr, palette = "RdYlGn",
                   order = suaci_2018_lyr['subcategoria'].value_counts().index)
ax2.set_xlabel("Numero de tramites",size = 14)
ax2.set_ylabel("Subcategorias",size = 14)
ax2.set_title('2018',size = 15)


#2019
ax3 = fig.add_subplot(3,1,3)
ax3 = sns.countplot(y="subcategoria",data= suaci_2019_lyr, palette = "RdYlGn",
                   order = suaci_2019_lyr['subcategoria'].value_counts().index)
ax3.set_xlabel("Numero de tramites",size = 14)
ax3.set_ylabel("Subcategorias",size = 14)
ax3.set_title('2019',size = 15)

plt.show()

# %% [markdown]
# 4. Dentro de las subcategorias que tienen mayor numero de reclamos... Que conceptos pesan mas?

# %% [markdown]
# TRANSITO - DENUNCIA VIAL

# %%
#2017
suaci_2017_dv = suaci_2017_clean.loc[suaci_2017_clean['SUBCATEGORIA'] == 'DENUNCIA VIAL']
#suaci_2017_dv.head()

#2018
suaci_2018_dv = suaci_2018_clean.loc[suaci_2018_clean['subcategoria'] == 'DENUNCIA VIAL']
#suaci_2018_dv.head()

#2019
suaci_2019_dv = suaci_2019_clean.loc[suaci_2019_clean['subcategoria'] == 'DENUNCIA VIAL']
#suaci_2019_dv.head()

# %%
fig = plt.figure(figsize=(6,6))
fig.subplots_adjust(top=0.85, hspace=1.5)
fig.suptitle('Conceptos de los Tramites de Denuncia Vial por Año', size = 18)

#2017
ax1 = fig.add_subplot(3,1,1)
ax1 = sns.countplot(y="CONCEPTO",data= suaci_2017_dv, palette = "RdYlGn",
                       order = ['VEHICULO MAL ESTACIONADO', 'VEHICULO OBSTRUYENDO GARAJE'])
ax1.set_xlabel("Numero de tramites",size = 14)
ax1.set_ylabel("Concepto",size = 14)
ax1.set_title('2017',size = 15)

#2018
ax2 = fig.add_subplot(3,1,2)
ax2 = sns.countplot(y="concepto",data= suaci_2018_dv, palette = "RdYlGn",
                   order = suaci_2018_dv['concepto'].value_counts().index)
ax2.set_xlabel("Numero de tramites",size = 14)
ax2.set_ylabel("Concepto",size = 14)
ax2.set_title('2018',size = 15)

#2018
ax3 = fig.add_subplot(3,1,3)
ax3 = sns.countplot(y="concepto",data= suaci_2019_dv, palette = "RdYlGn",
                   order = suaci_2019_dv['concepto'].value_counts().index)
ax3.set_xlabel("Numero de tramites",size = 14)
ax3.set_ylabel("Concepto",size = 14)
ax3.set_title('2019',size = 15)

plt.show()

# %% [markdown]
# LIMPIEZA Y RECOLECCION - RESIDUOS VOLUMINOSOS

# %%
#2017
suaci_2017_rv = suaci_2017_clean.loc[suaci_2017_clean['SUBCATEGORIA'] == 'RESIDUOS VOLUMINOSOS']
#suaci_2017_rv.head()

#2018
suaci_2018_rv = suaci_2018_clean.loc[suaci_2018_clean['subcategoria'] == 'RESIDUOS VOLUMINOSOS']
#suaci_2018_rv.head()

#2019
suaci_2019_rv = suaci_2019_clean.loc[suaci_2019_clean['subcategoria'] == 'RESIDUOS VOLUMINOSOS']
#suaci_2019_rv.head()

# %%
fig = plt.figure(figsize=(6,7))
fig.subplots_adjust(top=0.87, hspace=1.2)
fig.suptitle('Conceptos de los Tramites de Residuos Voluminosos por Año', size = 18)

#2017
ax1 = fig.add_subplot(3,1,1)
ax1 = sns.countplot(y="CONCEPTO",data= suaci_2017_rv, palette = "RdYlGn")
ax1.set_xlabel("Numero de tramites",size = 14)
ax1.set_ylabel("Concepto",size = 14)
ax1.set_title('2017',size = 15)

#2018
ax2 = fig.add_subplot(3,1,2)
ax2 = sns.countplot(y="concepto",data= suaci_2018_rv, palette = "RdYlGn",
                   order = suaci_2018_rv['concepto'].value_counts().index)
ax2.set_xlabel("Numero de tramites",size = 14)
ax2.set_ylabel("Concepto",size = 14)
ax2.set_title('2018',size = 15)


#2019
ax3 = fig.add_subplot(3,1,3)
ax3 = sns.countplot(y="concepto",data= suaci_2019_rv, palette = "RdYlGn",
                   order = suaci_2019_rv['concepto'].value_counts().index)
ax3.set_xlabel("Numero de tramites",size = 14)
ax3.set_ylabel("Concepto",size = 14)
ax3.set_title('2019',size = 15)

plt.show()

# %% [markdown]
# 5. Numeros de tramites por genero en los años 2017-2019. De que genero son la mayoria de los tramies/reclamos?

# %%
fig = plt.figure(figsize=(8,4))
fig.subplots_adjust(top=0.8, wspace=1)
fig.suptitle('Tramites por Genero por Año', size = 18)

#2017
ax1 = fig.add_subplot(1,3,1)
ax1 = sns.countplot(x="GENERO",data=suaci_2017_clean, palette = "RdYlGn",
                    order = suaci_2017_clean['GENERO'].value_counts().index)              
ax1.set_xticklabels(ax1.get_xticklabels(), rotation=40, ha="right")
ax1.set_xlabel("Generos",size = 14)
ax1.set_ylabel("Numero de tramites",size = 14)
ax1.set_title('2017',size = 15)

#2018
ax2 = fig.add_subplot(1,3,2)
ax2 = sns.countplot(x="genero",data=suaci_2018_clean, palette = "RdYlGn")              
ax2.set_xticklabels(ax2.get_xticklabels(), rotation=40, ha="right")
ax2.set_xlabel("Generos",size = 14)
ax2.set_ylabel("Numero de tramites",size = 14)
ax2.set_title('2018',size = 15)

#2019
ax3 = fig.add_subplot(1,3,3)
ax3 = sns.countplot(x="genero",data=suaci_2019_clean, palette = "RdYlGn")              
ax3.set_xticklabels(ax3.get_xticklabels(), rotation=40, ha="right")
ax3.set_xlabel("Generos",size = 14)
ax3.set_ylabel("Numero de tramites",size = 14)
ax3.set_title('2019',size = 15)

plt.show()

# %% [markdown]
# 6. Tipo de prestacion mas comun por año

# %%
fig = plt.figure(figsize=(10,5))
fig.subplots_adjust(top=0.8, wspace=0.75)
fig.suptitle('Tipo de Prestacion de Tramites por Año', size = 18)

#2017
ax1 = fig.add_subplot(1,3,1)
ax1 = sns.countplot(x="TIPO_PRESTACION",data=suaci_2017_clean, palette = "RdYlGn",
                   order = suaci_2017_clean['TIPO_PRESTACION'].value_counts().index)              
ax1.set_xticklabels(ax1.get_xticklabels(), rotation=40, ha="right")
ax1.set_xlabel("Prestacion",size = 14)
ax1.set_ylabel("Numero de tramites",size = 14)
ax1.set_title('2017',size = 15)

#2018
ax2 = fig.add_subplot(1,3,2)
ax2 = sns.countplot(x="tipo_prestacion",data=suaci_2018_clean, palette = "RdYlGn",
                   order = suaci_2018_clean['tipo_prestacion'].value_counts().index)              
ax2.set_xticklabels(ax2.get_xticklabels(), rotation=40, ha="right")
ax2.set_xlabel("Prestacion",size = 14)
ax2.set_ylabel("Numero de tramites",size = 14)
ax2.set_title('2018',size = 15)

#2019
ax3 = fig.add_subplot(1,3,3)
ax3 = sns.countplot(x="tipo_prestacion",data=suaci_2019_clean, palette = "RdYlGn",
                   order = suaci_2019_clean['tipo_prestacion'].value_counts().index)              
ax3.set_xticklabels(ax3.get_xticklabels(), rotation=40, ha="right")
ax3.set_xlabel("Prestacion",size = 14)
ax3.set_ylabel("Numero de tramites",size = 14)
ax3.set_title('2019',size = 15)

plt.show()

# %% [markdown]
# 7. Canal de comunicacion mas comun por año

# %%
fig = plt.figure(figsize=(10,5))
fig.subplots_adjust(top=0.8, wspace=1)
fig.suptitle('Medio de Comunicacion por Año', size = 18)

#2017
ax1 = fig.add_subplot(1,3,1)
ax1 = sns.countplot(x="CANAL",data= suaci_2017_clean, palette = "RdYlGn",
                   order = ['APP', 'WEB', '147','COMUNAS'])
ax1.set_xticklabels(ax1.get_xticklabels(), rotation=40, ha="right")
ax1.set_ylabel("Numero de tramites",size = 14)
ax1.set_xlabel("Canal",size = 14)
ax1.set_title('2017',size = 15)

#2018
ax2 = fig.add_subplot(1,3,2)
ax2 = sns.countplot(x="canal",data= suaci_2018_clean, palette = "RdYlGn")
ax2.set_xticklabels(ax2.get_xticklabels(), rotation=40, ha="right")
ax2.set_ylabel("Numero de tramites",size = 14)
ax2.set_xlabel("Canal",size = 14)
ax2.set_title('2018',size = 15)

#2019
ax3 = fig.add_subplot(1,3,3)
ax3 = sns.countplot(x="canal",data= suaci_2019_clean, palette = "RdYlGn")
ax3.set_xticklabels(ax3.get_xticklabels(), rotation=40, ha="right")
ax3.set_ylabel("Numero de tramites",size = 14)
ax3.set_xlabel("Canal",size = 14)
ax3.set_title('2019',size = 15)

plt.show()

# %% [markdown]
# 8. Estado de los casos por año
# Esto lo hice con los datos sin limpiar porque sino en los años 2018 y 2019 no tenia casos Abiertos

# %%
fig = plt.figure(figsize=(8,4))
fig.subplots_adjust(top=0.8, wspace=3)
fig.suptitle('Estado de Tramites por Año', size = 18)

#2017
ax1 = fig.add_subplot(1,3,1)
ax1 = sns.countplot(x="ESTADO_DEL_CONTACTO",data=suaci_2017_clean, palette = "RdYlGn",
                   order = suaci_2017['ESTADO_DEL_CONTACTO'].value_counts().index)              
ax1.set_xticklabels(ax1.get_xticklabels(), rotation=40, ha="right")
ax1.set_xlabel("Estado",size = 14)
ax1.set_ylabel("Numero de tramites",size = 14)
ax1.set_title('2017',size = 15)

#2018
ax2 = fig.add_subplot(1,3,2)
ax2 = sns.countplot(x="estado_del_contacto",data=suaci_2018, palette = "RdYlGn",
                   order = suaci_2018['estado_del_contacto'].value_counts().index)              
ax2.set_xticklabels(ax2.get_xticklabels(), rotation=40, ha="right")
ax2.set_xlabel("Estado",size = 14)
ax2.set_ylabel("Numero de tramites",size = 14)
ax2.set_title('2018',size = 15)

#2019
ax3 = fig.add_subplot(1,3,3)
ax3 = sns.countplot(x="estado_del_contacto",data=suaci_2019, palette = "RdYlGn",
                   order = suaci_2019['estado_del_contacto'].value_counts().index)              
ax3.set_xticklabels(ax3.get_xticklabels(), rotation=40, ha="right")
ax3.set_xlabel("Estado",size = 14)
ax3.set_ylabel("Numero de tramites",size = 14)
ax3.set_title('2019',size = 15)

plt.show()

# %% [markdown]
# 9.Evolución temporal de los Contactos al SUACI

# %%
#2017
suaci_2017_clean['FECHA_INGRESO'] = pd.to_datetime(suaci_2017_clean['FECHA_INGRESO'])
suaci_2017_clean['anio'] = suaci_2017_clean['FECHA_INGRESO'].dt.year
suaci_2017_clean['mes'] = suaci_2017_clean['FECHA_INGRESO'].dt.month
suaci_2017_clean_contactos_periodo = pd.pivot_table(suaci_2017_clean, values = 'CANAL', index = 'mes', columns = 'anio', aggfunc = 'count')

#2018
suaci_2018_clean['fecha_ingreso'] = pd.to_datetime(suaci_2018_clean['fecha_ingreso'])
suaci_2018_clean['anio'] = suaci_2018_clean['fecha_ingreso'].dt.year
suaci_2018_clean['mes'] = suaci_2018_clean['fecha_ingreso'].dt.month
suaci_2018_clean_contactos_periodo = pd.pivot_table(suaci_2018_clean, values = 'canal', index = 'mes', columns = 'anio', aggfunc = 'count')

#2019
suaci_2019_clean['fecha_ingreso'] = pd.to_datetime(suaci_2019_clean['fecha_ingreso'])
suaci_2019_clean['anio'] = suaci_2019_clean['fecha_ingreso'].dt.year
suaci_2019_clean['mes'] = suaci_2019_clean['fecha_ingreso'].dt.month
suaci_2019_clean_contactos_periodo = pd.pivot_table(suaci_2019_clean, values = 'canal', index = 'mes', columns = 'anio', aggfunc = 'count')


plt.figure(figsize=(9,5))
plt.xticks(np.arange(0, 13, 1.0))
plt.plot(suaci_2017_clean_contactos_periodo.index, suaci_2017_clean_contactos_periodo[2017], label='2017', color='#a6d96a');
plt.plot(suaci_2018_clean_contactos_periodo.index, suaci_2018_clean_contactos_periodo[2018], label='2018',color='#fee08b');
plt.plot(suaci_2019_clean_contactos_periodo.index, suaci_2019_clean_contactos_periodo[2019], label='2019',color='#f46d43');
plt.legend(loc='upper right')
plt.title('Evolución temporal de los Contactos al SUACI', fontsize=16)
plt.ylabel('Cantidad de Tramites', size = 14)
plt.xlabel('Mes',size = 14)
plt.show()

# %% [markdown]
# 9. Tiempo de resolucion promedio de los tramites por Categoria

# %%
# Voy a crear un el campo llamado 'plazo_resolución' = diferencia entre la fechas de apertura y cierre de contacto en DIAS
# Esta FEATURE voy a usarla para ver el tiempo medio de resolucion de los tramites y un boxplot de los mismos.

#2017
#NO tiene la FEATURE fecha_cierre_contacto... asi que no podremos visualizar el plazo de resolucion

#2018
suaci_2018_clean['fecha_cierre_contacto'] = pd.to_datetime(suaci_2018_clean['fecha_cierre_contacto'])
suaci_2018_clean['fecha_ingreso'] = pd.to_datetime(suaci_2018_clean['fecha_ingreso'])
suaci_2018_clean['plazo_resolucion'] = suaci_2018_clean['fecha_cierre_contacto'] - suaci_2018_clean['fecha_ingreso']
suaci_2018_clean['plazo_resolucion'] = suaci_2018_clean['plazo_resolucion'].dt.days
#Tiempo Medio de resolucion 2018
suaci_2018_clean_plazos_categoria_media = suaci_2018_clean.groupby('categoria')['plazo_resolucion'].mean()


#2019
suaci_2019_clean['fecha_cierre_contacto'] = pd.to_datetime(suaci_2019_clean['fecha_cierre_contacto'])
suaci_2019_clean['fecha_ingreso'] = pd.to_datetime(suaci_2019_clean['fecha_ingreso'])
suaci_2019_clean['plazo_resolucion'] = suaci_2019_clean['fecha_cierre_contacto'] - suaci_2019_clean['fecha_ingreso']
suaci_2019_clean['plazo_resolucion'] = suaci_2019_clean['plazo_resolucion'].dt.days
#Tiempo Medio de resolucion 2019
suaci_2019_clean_plazos_categoria_media = suaci_2019_clean.groupby('categoria')['plazo_resolucion'].mean()

# %% [markdown]
# Barplot del Tiempo Medio de Resolucion de los Tramites por Categoria

# %%
fig = plt.figure(figsize=(15,5))
fig.subplots_adjust(top=0.8, wspace=0.2)
fig.suptitle('Tiempo Medio de Resolucion de los Tramites por Categoria', size = 18)

#2018
ax1 = fig.add_subplot(1,2,1)
ax1= sns.barplot(x="categoria", y="plazo_resolucion", data=suaci_2018_clean, palette="RdYlGn",
                   order = ['ALUMBRADO','ARBOLADO Y ESPACIOS VERDES','CALLES Y VEREDAS','CONTROL EDILICIO, OBRAS Y CATASTRO',
                            'FISCALIZACIÓN ACTIVIDADES COMERCIALES','LIMPIEZA Y RECOLECCIÓN','MEDIOS DE TRANSPORTE',
                            'ORDENAMIENTO DEL ESPACIO PÚBLICO','PLUVIALES','RECICLADO Y PROTECCIÓN AMBIENTAL',
                            'SALUD Y SERVICIOS SOCIALES','SEGURIDAD','TRÁMITES Y SERVICIOS',
                            'TRÁNSITO'])            
ax1.set_xticklabels(ax1.get_xticklabels(), rotation=40, ha="right")
ax1.set_xlabel("Categorias",size = 14)
ax1.set_ylabel("Tiempo de Resolución (dias)",size = 14)
ax1.set_title('2018',size = 15)

#2019
ax2 = fig.add_subplot(1,2,2)
ax2= sns.barplot(x="categoria", y="plazo_resolucion", data=suaci_2019_clean, palette="RdYlGn",
                   order = ['ALUMBRADO','ARBOLADO Y ESPACIOS VERDES','CALLES Y VEREDAS','CONTROL EDILICIO, OBRAS Y CATASTRO',
                            'FISCALIZACIÓN ACTIVIDADES COMERCIALES','LIMPIEZA Y RECOLECCIÓN','MEDIOS DE TRANSPORTE',
                            'ORDENAMIENTO DEL ESPACIO PÚBLICO','PLUVIALES','RECICLADO Y PROTECCIÓN AMBIENTAL',
                            'SALUD Y SERVICIOS SOCIALES','SEGURIDAD','TRÁMITES Y SERVICIOS',
                            'TRÁNSITO'])           
ax2.set_xticklabels(ax2.get_xticklabels(), rotation=40, ha="right")
ax2.set_xlabel("Categorias",size = 14)
ax2.set_ylabel("Tiempo de Resolución (dias)",size = 14)
ax2.set_title('2019',size = 15)

plt.show()

# %% [markdown]
# Boxplot del Tiempo de Resolucion de los Tramites por Categoria

# %%
fig = plt.figure(figsize=(15,5))
fig.subplots_adjust(top=0.8, wspace=0.2)
fig.suptitle('Tiempo de Resolucion de los Tramites por Categoria', size = 18)


#2018
ax1 = fig.add_subplot(1,2,1)
ax1 = sns.boxplot(x='categoria', y='plazo_resolucion', data=suaci_2018_clean, palette = "RdYlGn",
                   order = ['ALUMBRADO','ARBOLADO Y ESPACIOS VERDES','CALLES Y VEREDAS','CONTROL EDILICIO, OBRAS Y CATASTRO',
                            'FISCALIZACIÓN ACTIVIDADES COMERCIALES','LIMPIEZA Y RECOLECCIÓN','MEDIOS DE TRANSPORTE',
                            'ORDENAMIENTO DEL ESPACIO PÚBLICO','PLUVIALES','RECICLADO Y PROTECCIÓN AMBIENTAL',
                            'SALUD Y SERVICIOS SOCIALES','SEGURIDAD','TRÁMITES Y SERVICIOS',
                            'TRÁNSITO'])
ax1.set_xticklabels(ax1.get_xticklabels(), rotation=40, ha="right")
ax1.set_xlabel("Categorias",size = 14)
ax1.set_ylabel("Tiempo de Resolución (dias)",size = 14)
ax1.set_title('2018',size = 15)


#2019
ax2 = fig.add_subplot(1,2,2)
ax2 = sns.boxplot(x='categoria', y='plazo_resolucion', data=suaci_2019_clean, palette = "RdYlGn",
                   order = ['ALUMBRADO','ARBOLADO Y ESPACIOS VERDES','CALLES Y VEREDAS','CONTROL EDILICIO, OBRAS Y CATASTRO',
                            'FISCALIZACIÓN ACTIVIDADES COMERCIALES','LIMPIEZA Y RECOLECCIÓN','MEDIOS DE TRANSPORTE',
                            'ORDENAMIENTO DEL ESPACIO PÚBLICO','PLUVIALES','RECICLADO Y PROTECCIÓN AMBIENTAL',
                            'SALUD Y SERVICIOS SOCIALES','SEGURIDAD','TRÁMITES Y SERVICIOS',
                            'TRÁNSITO'])
ax2.set_xticklabels(ax2.get_xticklabels(), rotation=40, ha="right")
ax2.set_xlabel("Categorias",size = 14)
ax2.set_ylabel("Tiempo de Resolución (dias)",size = 14)
ax2.set_title('2019',size = 15)

plt.show()
